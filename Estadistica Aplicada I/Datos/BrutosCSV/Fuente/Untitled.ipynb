# %%
import pandas as pd

# %%
df= pd.read_csv('FueFem2008_sinuefeff.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-17ace933b107> in <module>()
# ----> 1 df= pd.read_csv('FueFem2008_sinuefeff.csv')
#
# ...

# %%
df.head()
# Out:
#                 Estado  SALUD   IMSS-ORD   ISSSTE  IMSS-OP    DIF  PEMEX   \
# 0       Aguascalientes     76           0        0    N.A.      0   N.A.
# 1      Baja California    266           3        0       1   N.A.   N.A.
# 2  Baja California Sur    152           1        1    N.A.   N.A.   N.A.
# 3             Campeche    745           0        0       1      0      0
# 4             Coahuila     59           0        4      22      0   N.A.
#
#    SEDENA  SEMAR  Otras  Total
# 0        0  N.A.      3     79
# 1        4     0     29    303
# 2        0     0   N.A.    154
# 3        0     0      0    746
# 4        0  N.A.     24    109

# %%
df['Estado'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-33402bc95410> in <module>()
# ----> 1 df['Estado'].unique()
#
# /Users/dangeles/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Users/dangeles/anaconda3/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /Users/dangeles/anaconda3/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
# ...

# %%
print(u'Estado')
# Out:
# Estado

# %%
df
# Out:
#                  Estado    SALUD   IMSS-ORD   ISSSTE  IMSS-OP    DIF  PEMEX   \
# 0        Aguascalientes       76           0        0    N.A.      0   N.A.
# 1       Baja California      266           3        0       1   N.A.   N.A.
# 2   Baja California Sur      152           1        1    N.A.   N.A.   N.A.
# 3              Campeche      745           0        0       1      0      0
# 4              Coahuila       59           0        4      22      0   N.A.
# 5                Colima       99           0        1    N.A.      0   N.A.
# 6               Chiapas      130           0       20      26   N.A.      0
# 7             Chihuahua    1 565           9        0      37   N.A.   N.A.
# 8      Distrito Federal      539           0      157       0      0      0
# 9               Durango       95           0        0      15      0   N.A.
# 10           Guanajuato    1 065           0        0       0   N.A.     10
# ...

# %%
df.columns
# Out:
# Index(['﻿Estado ', 'SALUD ', 'IMSS-ORD ', 'ISSSTE ', 'IMSS-OP ', 'DIF ',
#        'PEMEX ', 'SEDENA ', 'SEMAR ', 'Otras ', 'Total'],
#       dtype='object')

# %%
print('hi....'+ u'sdf \r hi')
# Out:
#  hi

# %%
print('Total')
# Out:
# Total
